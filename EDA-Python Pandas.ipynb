# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('basketball_stats_2022.csv')
df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %% [markdown]
# ##### Acronyms
# Acronym	 - Description
# Rk  - Rank
# Pos	 - Position
# Age	 - Player's age on February 1 of the season
# Tm	- Team
# G -	Games
# GS -	Games Started
# MP -	Minutes Played Per Game
# FG -	Field Goals Per Game
# FGA - 	Field Goal Attempts Per Game
# FG% - 	Field Goal Percentage
# 3P -	3-Point Field Goals Per Game
# 3PA -	3-Point Field Goal Attempts Per Game
# 3P% - 	FG% on 3-Pt FGAs.
# 2P - 	2-Point Field Goals Per Game
# 2PA - 	2-Point Field Goal Attempts Per Game
# 2P% - 	FG% on 2-Pt FGAs.
# eFG% -	Effective Field Goal Percentage
# (Note: This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.)
# FT - 	Free Throws Per Game
# FTA - 	Free Throw Attempts Per Game
# FT% -	Free Throw Percentage
# ORB -	Offensive Rebounds Per Game
# DRB -	Defensive Rebounds Per Game
# TRB -	Total Rebounds Per Game
# AST -	Assists Per Game
# STL -	Steals Per Game
# BLK -	Blocks Per Game
# TOV -	Turnovers Per Game
# PF -	Personal Fouls Per Game
# PTS -	Points Per Game

# %%
df.shape
# Out:
# (812, 30)

# %% [markdown]
# ###### Dataframe content, first 5 rows

# %%
df.head()
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0   1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  0.595
# 1   2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  0.543
# 2   3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  0.753
# 3   4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  0.625
# 4   5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  0.873
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
#
# [5 rows x 30 columns]

# %% [markdown]
# ###### Checking for missing values

# %%
df.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%       15
# 3P         0
# 3PA        0
# 3P%       72
# 2P         0
# 2PA        0
# 2P%       28
# eFG%      15
# FT         0
# FTA        0
# FT%       97
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ###### Replace missing values with 0

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
df=df.drop(['Rk'], axis=1)
df
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1         Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2          Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3         Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4    LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 807     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  ...
# 808         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 809     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 810        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 811        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
df.select_dtypes(include=['number'])
# Out:
#      Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...    FT%  ORB  \
# 0     22  73  28  23.6  3.6   8.3  0.439  0.8  2.1  0.359  ...  0.595  2.0
# 1     28  76  75  26.3  2.8   5.1  0.547  0.0  0.0  0.000  ...  0.543  4.6
# 2     24  56  56  32.6  7.3  13.0  0.557  0.0  0.1  0.000  ...  0.753  2.4
# 3     21  32   0  11.3  1.7   4.1  0.402  0.2  1.5  0.125  ...  0.625  1.0
# 4     36  47  12  22.3  5.4   9.7  0.550  0.3  1.0  0.304  ...  0.873  1.6
# ..   ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...    ...  ...
# 807   33  26   0  18.3  2.6   5.5  0.465  0.7  1.7  0.395  ...  0.481  1.5
# 808   23  76  76  34.9  9.4  20.3  0.460  3.1  8.0  0.382  ...  0.904  0.7
# 809   23  56  12  12.6  2.3   4.4  0.526  0.0  0.2  0.091  ...  0.623  1.5
# 810   29  27   0  13.1  1.9   3.3  0.567  0.0  0.1  0.000  ...  0.776  1.9
# 811   24  76  76  24.4  4.1   6.5  0.626  0.0  0.0  0.000  ...  0.727  2.9
#
#      DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.select_dtypes(include=['object'])
# Out:
#                 Player Pos   Tm
# 0     Precious Achiuwa   C  TOR
# 1         Steven Adams   C  MEM
# 2          Bam Adebayo   C  MIA
# 3         Santi Aldama  PF  MEM
# 4    LaMarcus Aldridge   C  BRK
# ..                 ...  ..  ...
# 807     Thaddeus Young  PF  TOR
# 808         Trae Young  PG  ATL
# 809     Omer Yurtseven   C  MIA
# 810        Cody Zeller   C  POR
# 811        Ivica Zubac   C  LAC
#
# [812 rows x 3 columns]

# %%
df.PTS.max()
# Out:
# 30.6

# %%
player_maxpts = df[df.PTS == df.PTS.max()]
player_maxpts
# Out:
#           Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 206  Joel Embiid   C   27  PHI  68  68  33.8  9.8  19.6  0.499  ...  0.814
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 206  2.1  9.6  11.7  4.2  1.1  1.5  3.1  2.7  30.6
#
# [1 rows x 29 columns]

# %% [markdown]
# ###### Which player scored most points per game (PTS)?

# %%
player_maxpts.Player
# Out:
# 206    Joel Embiid
# Name: Player, dtype: object

# %% [markdown]
# ###### Which team is the player from?

# %%
player_maxpts.Tm
# Out:
# 206    PHI
# Name: Tm, dtype: object

# %% [markdown]
# ###### Which position is the player playing as?

# %%
player_maxpts.Pos
# Out:
# 206    C
# Name: Pos, dtype: object

# %% [markdown]
# ###### How many games did the player play in the season?

# %%
player_maxpts.G
# Out:
# 206    68
# Name: G, dtype: int64

# %% [markdown]
# ###### Which player scored more than 20 Points (PTS) per game?

# %%
df[df.PTS>20]
# Out:
#                       Player    Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 15     Giannis Antetokounmpo     PF   27  MIL  67  67  32.9  10.3  18.6
# 32               LaMelo Ball     PG   20  CHO  75  75  32.3   7.2  16.7
# 48              Bradley Beal     SG   28  WAS  40  40  36.0   8.7  19.3
# 70              Devin Booker     SG   25  PHO  68  68  34.5   9.7  20.9
# 78             Miles Bridges     PF   23  CHO  80  80  35.5   7.5  15.2
# 93              Jaylen Brown     SF   25  BOS  66  66  33.6   8.7  18.4
# 106             Jimmy Butler     SF   32  MIA  57  57  33.9   7.0  14.5
# 159            Stephen Curry     PG   33  GSW  64  64  34.5   8.4  19.1
# 160            Anthony Davis      C   28  LAL  40  40  35.1   9.3  17.4
# 167            DeMar DeRozan     PF   32  CHI  76  76  36.1  10.2  20.2
# 178              Luka Dončić     PG   22  DAL  65  65  35.4   9.9  21.6
# 198             Kevin Durant     PF   33  BRK  55  55  37.2  10.5  20.3
# ...

# %% [markdown]
# ###### Which player has got the highest 3 -point goals per game (3P)?

# %%
df['3P'].max()
# Out:
# 4.5

# %%
df[df['3P']==df['3P'].max()]
# Out:
#             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 159  Stephen Curry  PG   33  GSW  64  64  34.5  8.4  19.1  0.437  ...  0.923
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 159  0.5  4.7  5.2  6.3  1.3  0.4  3.2  2.0  25.5
#
# [1 rows x 29 columns]

# %% [markdown]
# ###### Which player has the highest Assists per game (AST)?

# %%
df[df['AST'] == df['AST'].max()]
# Out:
#          Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 582  Chris Paul  PG   36  PHO  65  65  32.9  5.6  11.3  0.493  ...  0.837
#
#      ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 582  0.3  4.0  4.4  10.8  1.9  0.3  2.4  2.1  14.7
#
# [1 rows x 29 columns]

# %% [markdown]
# ###### Which player scored the highest (PTS) frm the Los Angeles Lakers?

# %%
LAL = df.groupby('Tm').get_group('LAL')
LAL
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 17       Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  0.441  ...
# 21          Trevor Ariza  SF   36  LAL  24  11  19.3   1.4   4.1  0.333  ...
# 24         D.J. Augustin  PG   34  LAL  21   0  17.8   1.9   4.1  0.453  ...
# 46         Kent Bazemore  SF   32  LAL  39  14  14.0   1.2   3.6  0.324  ...
# 74         Avery Bradley  SG   31  LAL  62  45  22.7   2.4   5.6  0.423  ...
# 90    Chaundee Brown Jr.  SF   23  LAL   2   0  10.5   0.5   3.5  0.143  ...
# 137      Darren Collison  PG   34  LAL   3   0  12.3   0.7   2.3  0.286  ...
# 160        Anthony Davis   C   28  LAL  40  40  35.1   9.3  17.4  0.532  ...
# 183      Sekou Doumbouya  PF   21  LAL   2   0   8.0   2.5   4.0  0.625  ...
# 205      Wayne Ellington  SG   34  LAL  43   9  18.8   2.3   5.5  0.414  ...
# 240       Wenyen Gabriel  PF   24  LAL  19   5  16.4   2.6   5.1  0.505  ...
# ...

# %%
LAL[LAL.PTS == LAL.PTS.max()]
# Out:
#            Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...    FT%  \
# 368  LeBron James  SF   37  LAL  56  56  37.2  11.4  21.8  0.524  ...  0.756
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 368  1.1  7.1  8.2  6.2  1.3  1.1  3.5  2.2  30.3
#
# [1 rows x 29 columns]

# %% [markdown]
# ###### Of the 5 Positions, on an average, which Position (Pos) scores the most points (PTS)?

# %%
df.groupby('Pos').PTS.describe()
# Out:
#        count       mean       std   min     25%    50%     75%   max
# Pos
# C      130.0   7.690769  5.621146   0.0   3.775   6.95   9.550  30.6
# C-PF     2.0  12.850000  8.555992   6.8   9.825  12.85  15.875  18.9
# PF     152.0   7.737500  6.036498   0.0   3.300   6.50  10.150  29.9
# PF-SF    1.0   8.500000       NaN   8.5   8.500   8.50   8.500   8.5
# PG     156.0   8.292308  6.684257   0.0   3.300   6.30  11.525  28.4
# PG-SG    1.0  22.000000       NaN  22.0  22.000  22.00  22.000  22.0
# SF     157.0   7.296178  6.206716   0.0   3.000   5.80   9.800  30.3
# SF-SG    5.0   8.660000  6.429852   3.1   3.800   7.30  10.100  19.0
# SG     199.0   7.810553  6.059656   0.0   2.950   6.20  11.250  26.8
# SG-PG    4.0   9.525000  5.701681   4.0   4.975   9.40  13.950  15.3
# SG-SF    5.0   7.360000  4.635515   3.5   3.900   6.20   8.300  14.9

# %% [markdown]
# ###### Showing only the 5 traditional positions namely, C, PF, PG, SF, SG (combinations to be removed from analysis)

# %%
positions = ['C', 'PF', 'PG', 'SF', 'SG']
POS = df[df.Pos.isin(positions)]
POS
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1         Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2          Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3         Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4    LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 807     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  ...
# 808         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 809     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 810        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 811        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
POS.groupby('Pos').PTS.describe()
# Out:
#      count      mean       std  min    25%   50%     75%   max
# Pos
# C    130.0  7.690769  5.621146  0.0  3.775  6.95   9.550  30.6
# PF   152.0  7.737500  6.036498  0.0  3.300  6.50  10.150  29.9
# PG   156.0  8.292308  6.684257  0.0  3.300  6.30  11.525  28.4
# SF   157.0  7.296178  6.206716  0.0  3.000  5.80   9.800  30.3
# SG   199.0  7.810553  6.059656  0.0  2.950  6.20  11.250  26.8

# %% [markdown]
# ###### Position Point Guard (PG), has the highest avg of around 8.3 points per game (PTS)

# %% [markdown]
# ###### Creating a subset of dataframe containing only Position (Pos) and Points per Game (PTS) columns

# %%
Pos_PTS = df[['Pos', 'PTS']]

positions = ['C', 'PF', 'PG', 'SF', 'SG']

Pos_PTS = Pos_PTS[Pos_PTS['Pos'].isin(positions)]

Pos_PTS
# Out:
#     Pos   PTS
# 0     C   9.1
# 1     C   6.9
# 2     C  19.1
# 3    PF   4.1
# 4     C  12.9
# ..   ..   ...
# 807  PF   6.3
# 808  PG  28.4
# 809   C   5.3
# 810   C   5.2
# 811   C  10.3
#
# [794 rows x 2 columns]

# %% [markdown]
# ###### Visualizations

# %%
Pos_PTS['PTS'].hist(by=Pos_PTS['Pos'], layout=(1,5), figsize = (16,2))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
sns.boxplot(x='Pos', y = 'PTS', data =Pos_PTS)
# Out:
# <AxesSubplot:xlabel='Pos', ylabel='PTS'>

# %%
sns.boxplot(x='Pos', y = 'PTS', data =Pos_PTS)
sns.stripplot(x='Pos', y = 'PTS', data =Pos_PTS, # with datapoints
             jitter = True,
             marker = 'o',
             alpha = 0.8,
             color = 'black')
# Out:
# <AxesSubplot:xlabel='Pos', ylabel='PTS'>

# %%
corr = df.corr()
round(corr,2)
# Out:
#        Age     G    GS    MP    FG   FGA   FG%    3P   3PA   3P%  ...   FT%  \
# Age   1.00  0.04  0.05  0.15  0.09  0.09  0.06  0.12  0.10  0.08  ...  0.08
# G     0.04  1.00  0.68  0.62  0.56  0.54  0.31  0.48  0.46  0.37  ...  0.47
# GS    0.05  0.68  1.00  0.75  0.74  0.71  0.23  0.53  0.52  0.23  ...  0.29
# MP    0.15  0.62  0.75  1.00  0.89  0.90  0.30  0.72  0.73  0.42  ...  0.50
# FG    0.09  0.56  0.74  0.89  1.00  0.97  0.36  0.68  0.68  0.35  ...  0.43
# FGA   0.09  0.54  0.71  0.90  0.97  1.00  0.21  0.76  0.79  0.37  ...  0.44
# FG%   0.06  0.31  0.23  0.30  0.36  0.21  1.00  0.05 -0.02  0.22  ...  0.26
# 3P    0.12  0.48  0.53  0.72  0.68  0.76  0.05  1.00  0.97  0.55  ...  0.44
# 3PA   0.10  0.46  0.52  0.73  0.68  0.79 -0.02  0.97  1.00  0.47  ...  0.42
# 3P%   0.08  0.37  0.23  0.42  0.35  0.37  0.22  0.55  0.47  1.00  ...  0.44
# 2P    0.05  0.48  0.67  0.77  0.94  0.86  0.42  0.38  0.39  0.18  ...  0.33
# ...

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize = (7,5))
sns.heatmap(corr, square = True)
# Out:
# <AxesSubplot:>

# %%
selections = ['Age', 'G', 'STL', 'BLK', 'AST', 'PTS']
dfs = df[selections]
dfs
# Out:
#      Age   G  STL  BLK  AST   PTS
# 0     22  73  0.5  0.6  1.1   9.1
# 1     28  76  0.9  0.8  3.4   6.9
# 2     24  56  1.4  0.8  3.4  19.1
# 3     21  32  0.2  0.3  0.7   4.1
# 4     36  47  0.3  1.0  0.9  12.9
# ..   ...  ..  ...  ...  ...   ...
# 807   33  26  1.2  0.4  1.7   6.3
# 808   23  76  0.9  0.1  9.7  28.4
# 809   23  56  0.3  0.4  0.9   5.3
# 810   29  27  0.3  0.2  0.8   5.2
# 811   24  76  0.5  1.0  1.6  10.3
#
# [812 rows x 6 columns]

# %%
g = sns.PairGrid(dfs)
g.map(plt.scatter)

# %% [markdown]
# ###### Points per Game (PTS) - positively correlated to Assists per Game (AST) and Steals per Game(STL), STL & AST are also positively correlated
